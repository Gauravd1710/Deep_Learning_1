# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauravd1710/Deep_Learning_1/blob/jdim/dl_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets transformers torch

# %%
# !pip install datasets -q

# %%
from datasets import load_dataset

dataset = load_dataset("coastalchp/ledgar")
print(dataset)

# %% [markdown]
# This error occurs because the notebook's metadata contains information about interactive widgets (`metadata.widgets`) which GitHub's renderer might not be able to process correctly, or the state information is missing. A common solution is to clear all cell outputs before saving and committing the notebook to GitHub. This removes any saved widget states that might be causing the conflict.

# %%
# look at a single example
print(dataset["train"][0])

# view all feature names
print(dataset["train"].features)
